# %% [markdown]
# # Thermal evolution of mantle and core

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import ticker, cm, colors
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Import interior_evolution class

# %%
from interior_evolution import *

# %% [markdown]
# ### Initialize simulation by choosing a planet (e.g. 'Mars')

# %%
q = interior_evolution(body='Mars')
# q = interior_evolution(body='blabla', inpfile='EarthLike_M2.0_Q3e-11.json')

# %% [markdown]
# ### Run evolution and choose tectonic mode ('SL': stagnant lid, 'ML': mobile lid)

# %%
q.calculate_evolution('SL')

# %% [markdown]
# ### Plot evolution of global quantities

# %%
plotf.plot_evolution(q)

# %% [markdown]
# ### Plot evolution of the temperature and viscosity profiles

# %%
plotf.plot_profiles_evolution(q)

# %% [markdown]
# ### Plot temperature and viscosity profiles at a given time (in Myr)

# %%
plotf.plot_profiles(q, 0, plot_solidus='yes', plot_liquidus='yes')

# %%
E=3e5
V=4e-6
Ts=730.
Tref=1600
Pref=3e9
Rg=8.3144
ds=210e3
P=4000*9*210e3
T=1706.15537813785
aa = 0.5
km = 3.
rhom=4000
alpha=3e-5
g = 9
D = (6050-3186)*1e3
kappa=1e-6

# eta = etaref*np.exp( (E + P*V)/(Rg*T) - (E + Pref*V)/(Rg*Tref) )
eta=9.8e20
# Ra = rhom*g*alpha*(T - Ts)*D**3./(kappa*eta)    
Ra=51953371.71172707
gamma = E*(T - Ts)/(Rg*T**2) 
gamma = E*(T - Ts)/(Rg*T*T)
qs = aa * km*(T - Ts) / D * gamma**(-4./3) * Ra**(1./3)
